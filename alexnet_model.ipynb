# %% [markdown]
# ### Import Dependencies

# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Import Datasets and Get Classes

# %%
for dirpath, dirnames, filenames in os.walk("Dataset"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")

bean_class = len(os.listdir("Dataset/train"))

dataset_dir = pathlib.Path("Dataset/train")
class_names = np.array(sorted([item.name for item in dataset_dir.glob("*")]))
print(class_names)
# Out:
# There are 3 directories and 0 images in Dataset
# There are 4 directories and 0 images in Dataset\test
# There are 0 directories and 450 images in Dataset\test\Dark
# There are 0 directories and 400 images in Dataset\test\Green
# There are 0 directories and 450 images in Dataset\test\Light
# There are 0 directories and 450 images in Dataset\test\Medium
# There are 4 directories and 0 images in Dataset\train
# There are 0 directories and 1250 images in Dataset\train\Dark
# There are 0 directories and 1200 images in Dataset\train\Green
# There are 0 directories and 1250 images in Dataset\train\Light
# There are 0 directories and 1250 images in Dataset\train\Medium
# There are 4 directories and 0 images in Dataset\val
# There are 0 directories and 450 images in Dataset\val\Dark
# There are 0 directories and 400 images in Dataset\val\Green
# There are 0 directories and 450 images in Dataset\val\Light
# There are 0 directories and 450 images in Dataset\val\Medium
# ['Dark' 'Green' 'Light' 'Medium']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Call the dataset

# %%
resize_transform = transforms.Compose([
    transforms.Resize((256, 256)),
])

image_dataset = datasets.ImageFolder(root='Dataset/train/',transform=resize_transform)

# %% [markdown]
# ##### Show image example in each class

# %%
# Define the classes of your dataset
classes = image_dataset.classes

# Create a figure with subplots for each class
fig, axes = plt.subplots(1, 4, figsize=(10, 5))

# Loop through each class and plot the first image
for i, cls in enumerate(classes):
    # Get the indices of the images for this class
    indices = [j for j, (x, y) in enumerate(image_dataset) if y == i]
    # Get the first image for this class
    img = image_dataset[indices[0]][0]
    img = img.resize((256,256))
    # Plot the image on the corresponding subplot
    axes[i].imshow(img)
    axes[i].set_title(cls)

plt.show()

# %% [markdown]
# ##### Create image preprocessing

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize( [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %% [markdown]
# ##### Show image transformation

# %%
example_image, _ = image_dataset[0]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(example_image)
ax[0].set_title('Before transform')
transformed_image = transform(example_image)
ax[1].imshow(transformed_image.permute(1, 2, 0))
ax[1].set_title('After transform')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### AlexNet Model Building

# %% [markdown]
# ##### Hyperparameter Setup

# %%
num_classes = 4
batch_size = 64
num_epochs = 64
learning_rate = 0.0001

# %% [markdown]
# ##### Apply preprocessing to transform the dataset

# %%
train_set = datasets.ImageFolder(root='Dataset/train/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)

val_set = datasets.ImageFolder(root='Dataset/val/', transform=transform)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False)

test_set = datasets.ImageFolder(root='Dataset/test/', transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Load pre-trained AlexNet model

# %%
model = models.alexnet(pretrained=True)

# %%
# Freeze all layers in the pre-trained model
for param in model.parameters():
    param.requires_grad = False

# %%
# Replace the last fully connected layer with a new one
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 10)

# %% [markdown]
# ##### Define loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.classifier[6].parameters(), lr=learning_rate)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train and Validate Model

# %% [markdown]
# ##### Train the model

# %%
# Train the model
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# Iterate over the validation dataset in batches
train_predictions = np.array([])
train_ground_truths = np.array([])

for epoch in range(num_epochs):
    # Training
    model.train()
    train_loss = 0.0
    train_total = 0
    train_correct = 0
    
    for i, (images, labels) in enumerate(train_loader):
        images = images.cuda()
        labels = labels.cuda()
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        
    train_losses.append(train_loss/train_total)
    train_accs.append(train_correct/train_total)
    
    # Validation
    model.eval()
    val_loss = 0.0
    val_total = 0
    val_correct = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            labels = labels.cuda()
            
            outputs = model(images)
            loss = criterion(outputs, labels)

            train_predictions = np.concatenate((train_predictions, predicted.cpu().numpy()))
            train_ground_truths = np.concatenate((train_ground_truths, labels.cpu().numpy()))

            
            val_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

        # remove the extra predictions
        if len(train_predictions) > len(train_ground_truths):
            train_predictions = train_predictions[:len(train_ground_truths)]

    # Convert predictions and true labels to numpy arrays
    train_predictions = np.array(train_predictions)
    train_ground_truths = np.array(train_ground_truths)
    
    val_losses.append(val_loss/val_total)
    val_accs.append(val_correct/val_total)
    
    # Print epoch statistics
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Val Loss: {:.4f}, Val Acc: {:.4f}'
          .format(epoch+1, num_epochs, train_losses[-1], train_accs[-1], val_losses[-1], val_accs[-1]))
# Out:
# Epoch [1/64], Train Loss: 0.9891, Train Acc: 0.7071, Val Loss: 0.4373, Val Acc: 0.9480
# Epoch [2/64], Train Loss: 0.3341, Train Acc: 0.9327, Val Loss: 0.2515, Val Acc: 0.9640
# Epoch [3/64], Train Loss: 0.2249, Train Acc: 0.9537, Val Loss: 0.1823, Val Acc: 0.9697
# Epoch [4/64], Train Loss: 0.1806, Train Acc: 0.9586, Val Loss: 0.1466, Val Acc: 0.9777
# Epoch [5/64], Train Loss: 0.1555, Train Acc: 0.9622, Val Loss: 0.1235, Val Acc: 0.9789
# Epoch [6/64], Train Loss: 0.1375, Train Acc: 0.9661, Val Loss: 0.1072, Val Acc: 0.9817
# Epoch [7/64], Train Loss: 0.1241, Train Acc: 0.9697, Val Loss: 0.0978, Val Acc: 0.9823
# Epoch [8/64], Train Loss: 0.1102, Train Acc: 0.9723, Val Loss: 0.0868, Val Acc: 0.9851
# Epoch [9/64], Train Loss: 0.1052, Train Acc: 0.9717, Val Loss: 0.0811, Val Acc: 0.9834
# Epoch [10/64], Train Loss: 0.0973, Train Acc: 0.9713, Val Loss: 0.0762, Val Acc: 0.9851
# Epoch [11/64], Train Loss: 0.0865, Train Acc: 0.9782, Val Loss: 0.0691, Val Acc: 0.9840
# Epoch [12/64], Train Loss: 0.0871, Train Acc: 0.9770, Val Loss: 0.0651, Val Acc: 0.9857
# Epoch [13/64], Train Loss: 0.0858, Train Acc: 0.9737, Val Loss: 0.0639, Val Acc: 0.9851
# Epoch [14/64], Train Loss: 0.0846, Train Acc: 0.9731, Val Loss: 0.0569, Val Acc: 0.9874
# Epoch [15/64], Train Loss: 0.0776, Train Acc: 0.9766, Val Loss: 0.0592, Val Acc: 0.9857
# Epoch [16/64], Train Loss: 0.0723, Train Acc: 0.9786, Val Loss: 0.0522, Val Acc: 0.9869
# Epoch [17/64], Train Loss: 0.0757, Train Acc: 0.9774, Val Loss: 0.0511, Val Acc: 0.9886
# Epoch [18/64], Train Loss: 0.0733, Train Acc: 0.9776, Val Loss: 0.0519, Val Acc: 0.9869
# Epoch [19/64], Train Loss: 0.0741, Train Acc: 0.9754, Val Loss: 0.0474, Val Acc: 0.9903
# Epoch [20/64], Train Loss: 0.0707, Train Acc: 0.9794, Val Loss: 0.0463, Val Acc: 0.9891
# Epoch [21/64], Train Loss: 0.0635, Train Acc: 0.9818, Val Loss: 0.0459, Val Acc: 0.9880
# Epoch [22/64], Train Loss: 0.0601, Train Acc: 0.9812, Val Loss: 0.0461, Val Acc: 0.9886
# Epoch [23/64], Train Loss: 0.0688, Train Acc: 0.9770, Val Loss: 0.0434, Val Acc: 0.9886
# Epoch [24/64], Train Loss: 0.0661, Train Acc: 0.9796, Val Loss: 0.0434, Val Acc: 0.9874
# Epoch [25/64], Train Loss: 0.0605, Train Acc: 0.9810, Val Loss: 0.0402, Val Acc: 0.9897
# Epoch [26/64], Train Loss: 0.0600, Train Acc: 0.9824, Val Loss: 0.0397, Val Acc: 0.9903
# Epoch [27/64], Train Loss: 0.0611, Train Acc: 0.9810, Val Loss: 0.0387, Val Acc: 0.9903
# Epoch [28/64], Train Loss: 0.0550, Train Acc: 0.9844, Val Loss: 0.0362, Val Acc: 0.9926
# Epoch [29/64], Train Loss: 0.0567, Train Acc: 0.9822, Val Loss: 0.0394, Val Acc: 0.9869
# Epoch [30/64], Train Loss: 0.0534, Train Acc: 0.9853, Val Loss: 0.0351, Val Acc: 0.9903
# Epoch [31/64], Train Loss: 0.0560, Train Acc: 0.9822, Val Loss: 0.0317, Val Acc: 0.9926
# Epoch [32/64], Train Loss: 0.0536, Train Acc: 0.9840, Val Loss: 0.0321, Val Acc: 0.9920
# Epoch [33/64], Train Loss: 0.0568, Train Acc: 0.9828, Val Loss: 0.0335, Val Acc: 0.9909
# Epoch [34/64], Train Loss: 0.0557, Train Acc: 0.9820, Val Loss: 0.0326, Val Acc: 0.9909
# Epoch [35/64], Train Loss: 0.0486, Train Acc: 0.9853, Val Loss: 0.0335, Val Acc: 0.9891
# Epoch [36/64], Train Loss: 0.0526, Train Acc: 0.9820, Val Loss: 0.0330, Val Acc: 0.9914
# Epoch [37/64], Train Loss: 0.0511, Train Acc: 0.9842, Val Loss: 0.0296, Val Acc: 0.9914
# Epoch [38/64], Train Loss: 0.0509, Train Acc: 0.9836, Val Loss: 0.0318, Val Acc: 0.9909
# Epoch [39/64], Train Loss: 0.0487, Train Acc: 0.9848, Val Loss: 0.0315, Val Acc: 0.9903
# Epoch [40/64], Train Loss: 0.0478, Train Acc: 0.9840, Val Loss: 0.0283, Val Acc: 0.9926
# Epoch [41/64], Train Loss: 0.0502, Train Acc: 0.9822, Val Loss: 0.0293, Val Acc: 0.9931
# Epoch [42/64], Train Loss: 0.0507, Train Acc: 0.9832, Val Loss: 0.0272, Val Acc: 0.9937
# Epoch [43/64], Train Loss: 0.0479, Train Acc: 0.9836, Val Loss: 0.0278, Val Acc: 0.9931
# Epoch [44/64], Train Loss: 0.0461, Train Acc: 0.9846, Val Loss: 0.0277, Val Acc: 0.9914
# Epoch [45/64], Train Loss: 0.0496, Train Acc: 0.9824, Val Loss: 0.0304, Val Acc: 0.9903
# Epoch [46/64], Train Loss: 0.0443, Train Acc: 0.9846, Val Loss: 0.0296, Val Acc: 0.9914
# Epoch [47/64], Train Loss: 0.0431, Train Acc: 0.9867, Val Loss: 0.0289, Val Acc: 0.9920
# Epoch [48/64], Train Loss: 0.0405, Train Acc: 0.9867, Val Loss: 0.0280, Val Acc: 0.9909
# Epoch [49/64], Train Loss: 0.0430, Train Acc: 0.9867, Val Loss: 0.0236, Val Acc: 0.9949
# Epoch [50/64], Train Loss: 0.0448, Train Acc: 0.9838, Val Loss: 0.0261, Val Acc: 0.9920
# Epoch [51/64], Train Loss: 0.0436, Train Acc: 0.9863, Val Loss: 0.0255, Val Acc: 0.9931
# Epoch [52/64], Train Loss: 0.0408, Train Acc: 0.9865, Val Loss: 0.0238, Val Acc: 0.9954
# Epoch [53/64], Train Loss: 0.0407, Train Acc: 0.9885, Val Loss: 0.0246, Val Acc: 0.9937
# Epoch [54/64], Train Loss: 0.0427, Train Acc: 0.9873, Val Loss: 0.0230, Val Acc: 0.9926
# Epoch [55/64], Train Loss: 0.0389, Train Acc: 0.9891, Val Loss: 0.0250, Val Acc: 0.9937
# Epoch [56/64], Train Loss: 0.0426, Train Acc: 0.9859, Val Loss: 0.0242, Val Acc: 0.9920
# Epoch [57/64], Train Loss: 0.0402, Train Acc: 0.9873, Val Loss: 0.0237, Val Acc: 0.9926
# Epoch [58/64], Train Loss: 0.0414, Train Acc: 0.9865, Val Loss: 0.0248, Val Acc: 0.9949
# Epoch [59/64], Train Loss: 0.0414, Train Acc: 0.9875, Val Loss: 0.0252, Val Acc: 0.9937
# Epoch [60/64], Train Loss: 0.0447, Train Acc: 0.9842, Val Loss: 0.0226, Val Acc: 0.9949
# Epoch [61/64], Train Loss: 0.0431, Train Acc: 0.9857, Val Loss: 0.0226, Val Acc: 0.9943
# Epoch [62/64], Train Loss: 0.0353, Train Acc: 0.9877, Val Loss: 0.0266, Val Acc: 0.9903
# Epoch [63/64], Train Loss: 0.0410, Train Acc: 0.9846, Val Loss: 0.0226, Val Acc: 0.9937
# Epoch [64/64], Train Loss: 0.0376, Train Acc: 0.9885, Val Loss: 0.0209, Val Acc: 0.9954

# %% [markdown]
# ##### Plot losses and accuracy

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.show()

plt.plot(train_accs, label='Train Acc')
plt.plot(val_accs, label='Val Acc')
plt.legend()
plt.show()

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
cm = confusion_matrix(train_ground_truths, train_predictions)
labels_category = ['Dark', 'Green', 'Light', 'Medium']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ##### Calculate the evaluation matrix

# %% [markdown]
# average_val = 'macro'
#
# accuracy = accuracy_score(train_ground_truths, train_predictions)
# precision = precision_score(train_ground_truths, train_predictions, average=average_val)
# recall = recall_score(train_ground_truths, train_predictions, average=average_val)
# f1 = f1_score(train_ground_truths, train_predictions, average=average_val)
#
# print(f"Accuracy: {round(accuracy * 100, 2)}%")
# print(f"Precision: {round(precision * 100, 2)}%")
# print(f"Recall: {round(recall * 100, 2)}%")
# print(f"F1 Score: {round(f1 * 100, 2)}%")

# %% [markdown]
# ### Testing Model

# %% [markdown]
# ##### Set to evaluation mode

# %%
# Set the model to evaluation mode
model.eval()

# Keep track of the validation loss and accuracy
test_loss = 0.0
test_correct = 0
test_total = 0

# %% [markdown]
# ##### Test the model

# %%
# Iterate over the validation dataset in batches
test_predictions = []
test_ground_truths = []

for images, labels in test_loader:
    images = images.cuda()
    labels = labels.cuda()
    # Forward pass
    outputs = model(images)
    loss = criterion(outputs, labels)

    # Update the validation loss
    test_loss += loss.item() * labels.size(0)

    test_predictions.extend(predicted.cpu().numpy())
    test_ground_truths.extend(labels.cpu().numpy())

    # Update the testing accuracy
    _, predicted = torch.max(outputs.data, 1)
    test_total += labels.size(0)
    test_correct += (predicted == labels).sum().item()

# Compute the average testing loss and accuracy
test_loss /= len(test_set)
test_accuracy = 100 * test_correct / test_total

# Print the testing loss and accuracy
print(f'Testing loss: {test_loss:.4f}, accuracy: {test_accuracy:.2f}%')
# Out:
# Testing loss: 0.0253, accuracy: 99.31%

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
# Calculate the confusion matrix
cm = confusion_matrix(test_ground_truths, test_predictions)
labels_category = ['Dark', 'Green', 'Light', 'Medium']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ##### Calculate the evaluation matrix

# %%
average_val = 'macro'

accuracy = accuracy_score(test_ground_truths, test_predictions)
precision = precision_score(test_ground_truths, test_predictions, average=average_val)
recall = recall_score(test_ground_truths, test_predictions, average=average_val)
f1 = f1_score(test_ground_truths, test_predictions, average=average_val)

print(f"Accuracy: {round(accuracy * 100, 2)}%")
print(f"Precision: {round(precision * 100, 2)}%")
print(f"Recall: {round(recall * 100, 2)}%")
print(f"F1 Score: {round(f1 * 100, 2)}%")

# %% [markdown]
# ##### Save the model

# %%
# Save the state_dict model to a file
torch.save(model.state_dict(), 'alexnet-coffee-roast-level-state-dict.pth')

# Save the model to a file
torch.save(model, 'alexnet-coffee-roast-level.pth')
